# %% [markdown]
# <a href="https://colab.research.google.com/github/kanipukima-pixel/alkhawaryzmi--TIF-26/blob/main/Alkhawaryzmi%20Brilliant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data1 ='alkhawaryzmi Brlliant '          # varabel yang bersi nama
data2 = 2605060011                       # variabel yang berisi NIM
data3 ='purworejo,10 januari 2008'       # variabel yang berisi tempat tanggal lahir
data4 ='Purworejo,Pangenjuru tengah '    # varabel yang bersi alamat
data5 = 'Laki-Laki'                      # variabel yang berisi jenis kelamin
data6 ='catur'                           # variabel yang berisi hobi

print(f'NAMA                  : {data1}')    # print untuk mencetak NAMA dan data1,sedangkan 'f' untuk menyisipka nilai
print(f'NIM                   : {data2}')    # print untuk mencetak NIM dan data1,sedangkan 'f' untuk menyisipka nilai
print(f'TEMPAT TANGGAL LAHIR  : {data3}')    # print untuk mencetak TEMPAT TANGGAL LAHIR dan data1,sedangkan 'f' untuk menyisipka nilai
print(f'ALAMAT                : {data4}')    # print untuk mencetak ALAMAT dan data1,sedangkan 'f' untuk menyisipka nilai
print(f'JENIS KELAMIN         : {data5}')    # print untuk mencetak JENIS KELAMIN dan data1,sedangkan 'f' untuk menyisipka nilai
print(f'HOBI                  : {data6}')    # print untuk mencetak HOBI dan data1,sedangkan 'f' untuk menyisipka nilai
# Out:
# NAMA                  : alkhawaryzmi Brlliant
# NIM                   : 2605060011
# TEMPAT TANGGAL LAHIR  : purworejo,10 januari 2008
# ALAMAT                : Purworejo,Pangenjuru tengah
# JENIS KELAMIN         : Laki-Laki
# HOBI                  : catur
