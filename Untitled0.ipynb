# %% [markdown]
# <a href="https://colab.research.google.com/github/kanipukima-pixel/alkhawaryzmi--TIF-26/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# alkha

# %%
print('HALO JOKOWI')
angka1=12
amgka2=78
print(f'jumlah = {angka1+amgka2}')
# Out:
# HALO JOKOWI
# jumlah = 90
